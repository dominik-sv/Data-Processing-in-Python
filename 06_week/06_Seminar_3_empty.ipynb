# %% [markdown]
# # Seminar 3: Data Formats and APIs
#
# March 25, 2025
# - Vilém Krejcar
#
# ______________________________

# %% [markdown]
# ## What are we going to learn
#
# - What are the most popular data formats and how to work with them
# - Databases, SQL and data manipulation
# - HTTP requests
# - How to scrape websites

# %% [markdown]
# ## 1. Data formats
#
# ### Data Serialization and Formats
# Serialization is the process of converting data structures or objects into a format that can be easily stored and shared. Common data formats in Python include:
# - **JSON**: Lightweight and commonly used for APIs.
# - **CSV**: Ideal for tabular data, especially in spreadsheets.
# - **Excel**: Classic data storage everyone is aware of.

# %% [markdown]
# #### JSON

# %%
import json
import pandas as pd
import os
    
data = {
    "name": "Alice",
    "age": 30,
    "is_member": True,
    "hobbies": ["reading", "biking", "coding"]
}

# %%
directory = 'Data'
file_path = os.path.join(directory, 'json_sample.json')
os.makedirs(directory, exist_ok=True)

with open(file_path, 'w') as f:
    json.dump(data, f)

# %%
with open(file_path, 'r') as f:
    data = pd.read_json(f)

with open(file_path, 'r') as f:
    data = json.load(f)

# %%
pd.DataFrame(data)
# Out:
#     name  age  is_member  hobbies
# 0  Alice   30       True  reading
# 1  Alice   30       True   biking
# 2  Alice   30       True   coding

# %% [markdown]
# #### CSV

# %%
import csv

data = [
    ["Name", "Age", "Occupation"],
    ["Alice", 30, "Engineer"],
    ["Bob", 25, "Designer"],
    ["Charlie", 35, "Teacher"]
]

# %%
directory = 'Data'
file_path = os.path.join(directory, 'sample_csv.csv')

os.makedirs(directory, exist_ok=True)

with open(file_path, 'w') as f:
    writer = csv.writer(f)
    writer.writerows(data)

# %%
csv_data = []
with open(file_path, 'r') as f:
    data = pd.read_csv(f)

with open(file_path, 'r') as f:
    csv_data = list(csv.reader(f))

# %%
csv_data
# Out:
# [['Name', 'Age', 'Occupation'],
#  [],
#  ['Alice', '30', 'Engineer'],
#  [],
#  ['Bob', '25', 'Designer'],
#  [],
#  ['Charlie', '35', 'Teacher'],
#  []]

# %% [markdown]
# #### Excel

# %%
data = {
    "name": "Thomas",
    "age": 30,
    "is_member": True,
    "hobbies": "reading, biking, coding"
}

# %%
directory = 'Data'
file_path = os.path.join(directory, 'sample_excel.xlsx')

os.makedirs(directory, exist_ok=True)

df = pd.DataFrame(data)

df.to_excel(file_path, index = False)

# %% [markdown]
# ## 2. Requests and web scraping

# %%
import requests # for making HTTP requests
import pandas as pd 
import time
import re # Regex = Regular Expressions

# %% [markdown]
# Time package small things:

# %%
# %%time
print("Hello, World!")
# Out:
# Hello, World!
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
t0 = time.time()
time.sleep(1)
t1 = time.time()
print("Time elapsed: ", t1-t0, " seconds")
# Out:
# Time elapsed:  1.0040500164031982  seconds

# %%
# %%time 
time.sleep(2)
# Out:
# CPU times: total: 0 ns
# Wall time: 2 s

# %%
import random

# %%
# %%time
r_time = random.uniform(0.5, 1.2)
print("Sleeping for ", r_time, " seconds")
time.sleep(r_time)
# Out:
# Sleeping for  0.8212864178980297  seconds
# CPU times: total: 0 ns
# Wall time: 822 ms

# %% [markdown]
# #### Task 1: Requesting API
#
# Let us work with data of sreality.cz which we can access via their api. An intuition is that the api is limited for a number of requests (but not verified).

# %% [markdown]
# ##### 1a. Create a function requesting data from sreality
#
# ```python
# base_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb=1&category_type_cb=1&locality_region_id=10&per_page60&page={}'.format(i)
#
# r = requests.get(base_url)
# d = r.json()
# ```
#
# 0) function should parametrize:
#     * `category_main_cb` - `{'flat':1, 'house':2, 'land':3 }`
#     * `category_type_cb` - `{'sell':1,'rent':2}`
#     * `locality_region_id` - use 10 as default value
#     * `page` parameter
# 1) use string inputs for `category_main_cb` and `category_type_cb`
# 2) include `try/except` clause to handle errors
# 3) function should return JSON data in python types
# 4) do not forget to sleep each request at least 0.5s

# %%
def request_sreality(page, category_main_str, category_type_str, locality_region_id=10):
    """
    Request data from sreality.cz API
    :param page: page number
    :param category_main_str: category of the property
    :param category_type_str: type of the offer
    :param locality_region_id: region id
    :return json: json response
    """
    category_mains = {'flat': 1, 'house': 2, 'land': 3}
    category_types = {'sell': 1, 'rent': 2}
    tempalte_url = 'https://www.sreality.cz/api/cs/v2/estates?category_main_cb={category_main}&category_type_cb={category_type}&locality_region_id={locality_region_id}&per_page60&page={page}'
    request_url = tempalte_url.format(
        category_main = category_mains[category_main_str],
        category_type = category_types[category_type_str],
        locality_region_id = locality_region_id,
        page = page
    )

    response_sleep = random.uniform(0.5, 1.2)
    time.sleep(response_sleep)

    try:
        response = requests.get(request_url)
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(e)
        return None

# %%
data = request_sreality(0, 'flat', 'rent')

# %% [markdown]
# Inspect the element `d`:

# %%
data.keys()
# Out:
# dict_keys(['meta_description', 'result_size', '_embedded', 'filterLabels', 'title', 'filter', '_links', 'locality', 'locality_dativ', 'logged_in', 'per_page', 'category_instrumental', 'page', 'filterLabels2'])

# %%
edata = data['_embedded']
edata.keys()
# Out:
# dict_keys(['estates', 'is_saved', 'not_precise_location_count'])

# %%
edata['estates'][0].keys()
# Out:
# dict_keys(['labelsReleased', 'has_panorama', 'labels', 'is_auction', 'labelsAll', 'seo', 'exclusively_at_rk', 'category', 'has_floor_plan', '_embedded', 'paid_logo', 'locality', 'has_video', 'advert_images_count', 'new', 'auctionPrice', 'type', 'hash_id', 'attractive_offer', 'price', 'price_czk', '_links', 'rus', 'name', 'region_tip', 'gps', 'has_matterport_url'])

# %%
column_names = edata['estates'][0].keys()
df = pd.DataFrame(columns=column_names)

# %%
df
# Out:
# Empty DataFrame
# Columns: [labelsReleased, has_panorama, labels, is_auction, labelsAll, seo, exclusively_at_rk, category, has_floor_plan, _embedded, paid_logo, locality, has_video, advert_images_count, new, auctionPrice, type, hash_id, attractive_offer, price, price_czk, _links, rus, name, region_tip, gps, has_matterport_url]
# Index: []
#
# [0 rows x 27 columns]

# %%
def convert_sreality_data_to_df(sreality_data):
    return pd.DataFrame(sreality_data['_embedded']['estates'])

# %%
df = convert_sreality_data_to_df(data)

# %%
df
# Out:
#                                     labelsReleased  has_panorama  \
# 0                     [[after_reconstruction], []]             0
# 1                   [[balcony, panel, cellar], []]             0
# 2                                         [[], []]             0
# 3                             [[balcony], [metro]]             0
# 4                             [[], [metro, medic]]             0
# 5            [[terrace, cellar, parking_lots], []]             0
# 6             [[new_building, loggia, cellar], []]             0
# 7                 [[cellar], [metro, post_office]]             0
# 8   [[after_reconstruction, partly_furnished], []]             0
# 9                                         [[], []]             0
# 10                                        [[], []]             0
# 11           [[terrace, parking_lots, garage], []]             0
# 12                             [[terrace], [shop]]             0
# 13                                        [[], []]             0
# 14                                        [[], []]             0
# 15                                 [[terrace], []]             0
# 16                             [[], [post_office]]             0
# 17                            [[], [metro, medic]]             0
# 18          [[new_building, balcony, terrace], []]             0
# 19         [[loggia, panel, partly_furnished], []]             0
# 20               [[after_reconstruction], [metro]]             0
#
#                                              labels  is_auction  \
# 0                                 [Po rekonstrukci]       False
# 1                         [Balkon, Panelová, Sklep]       False
# 2                                                []       False
# 3                      [Balkon, Metro 3 min. pěšky]       False
# 4    [Metro 242 metrů pěšky, Lékař 421 metrů pěšky]       False
# 5                        [Terasa, Sklep, Parkování]       False
# 6                       [Novostavba, Lodžie, Sklep]       False
# 7   [Sklep, Metro 3 min. pěšky, Pošta 2 min. pěšky]       False
# 8              [Po rekonstrukci, Částečně vybavený]       False
# 9                                                []       False
# 10                                               []       False
# 11                       [Terasa, Parkování, Garáž]       False
# 12                    [Terasa, Obchod 7 min. pěšky]       False
# 13                                               []       False
# 14                                               []       False
# 15                                         [Terasa]       False
# 16                             [Pošta 4 min. pěšky]       False
# 17         [Metro 6 min. pěšky, Lékař 6 min. pěšky]       False
# 18                     [Novostavba, Balkon, Terasa]       False
# 19            [Lodžie, Panelová, Částečně vybavený]       False
# 20            [Po rekonstrukci, Metro 6 min. pěšky]       False
#
#                                             labelsAll  \
# 0   [[personal, after_reconstruction, brick], [the...
# 1   [[personal, balcony, panel, cellar, elevator, ...
# 2   [[personal, furnished], [sports, restaurant, s...
# 3   [[personal, balcony, brick, elevator], [small_...
# 4   [[personal, brick, not_furnished], [theater, r...
# 5   [[personal, terrace, cellar, parking_lots, par...
# 6   [[new_building, personal, loggia, brick, cella...
# 7   [[personal, brick, cellar], [theater, vet, can...
# 8   [[personal, after_reconstruction, brick, eleva...
# 9   [[personal, brick, elevator, not_furnished], [...
# 10  [[personal, brick, elevator, furnished], [thea...
# 11  [[personal, terrace, brick, parking_lots, gara...
# 12  [[personal, terrace, brick, elevator, furnishe...
# 13  [[personal, brick, not_furnished], [theater, c...
# 14  [[personal, brick, not_furnished], [theater, c...
# 15  [[personal, terrace, brick, elevator, not_furn...
# 16  [[personal, brick, elevator, furnished], [thea...
# 17  [[personal, brick, elevator, not_furnished], [...
# 18  [[new_building, personal, balcony, terrace, br...
# 19  [[personal, loggia, panel, elevator, partly_fu...
# 20  [[personal, after_reconstruction, brick, eleva...
#
#                                                   seo  exclusively_at_rk  \
# 0   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 1   {'category_main_cb': 1, 'category_sub_cb': 47,...                  1
# 2   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 3   {'category_main_cb': 1, 'category_sub_cb': 2, ...                  0
# 4   {'category_main_cb': 1, 'category_sub_cb': 7, ...                  0
# 5   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 6   {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 7   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 8   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  1
# 9   {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 10  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
# 11  {'category_main_cb': 1, 'category_sub_cb': 11,...                  0
# 12  {'category_main_cb': 1, 'category_sub_cb': 9, ...                  0
# 13  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 14  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 15  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 16  {'category_main_cb': 1, 'category_sub_cb': 8, ...                  0
# 17  {'category_main_cb': 1, 'category_sub_cb': 5, ...                  0
# 18  {'category_main_cb': 1, 'category_sub_cb': 6, ...                  0
# 19  {'category_main_cb': 1, 'category_sub_cb': 2, ...                  1
# 20  {'category_main_cb': 1, 'category_sub_cb': 4, ...                  0
#
#     category  has_floor_plan  \
# 0          1               0
# 1          1               0
# 2          1               0
# 3          1               1
# 4          1               0
# 5          1               0
# 6          1               1
# 7          1               0
# 8          1               0
# 9          1               0
# 10         1               0
# 11         1               0
# 12         1               0
# 13         1               0
# 14         1               0
# 15         1               0
# 16         1               0
# 17         1               0
# 18         1               1
# 19         1               0
# 20         1               0
#
#                                             _embedded  ...     hash_id  \
# 0   {'favourite': {'is_favourite': False, '_links'...  ...  2900562508
# 1   {'favourite': {'is_favourite': False, '_links'...  ...  1445737036
# 2   {'favourite': {'is_favourite': False, '_links'...  ...   635466316
# 3   {'favourite': {'is_favourite': False, '_links'...  ...  1319072332
# 4   {'favourite': {'is_favourite': False, '_links'...  ...   168849996
# 5   {'favourite': {'is_favourite': False, '_links'...  ...   454062668
# 6   {'favourite': {'is_favourite': False, '_links'...  ...  2281796172
# 7   {'favourite': {'is_favourite': False, '_links'...  ...  2333110860
# 8   {'favourite': {'is_favourite': False, '_links'...  ...  1209037388
# 9   {'favourite': {'is_favourite': False, '_links'...  ...   231084620
# 10  {'favourite': {'is_favourite': False, '_links'...  ...  1500918348
# 11  {'favourite': {'is_favourite': False, '_links'...  ...  2024370764
# 12  {'favourite': {'is_favourite': False, '_links'...  ...  2341020236
# 13  {'favourite': {'is_favourite': False, '_links'...  ...  3281613388
# 14  {'favourite': {'is_favourite': False, '_links'...  ...  3698291276
# 15  {'favourite': {'is_favourite': False, '_links'...  ...  3777888844
# 16  {'favourite': {'is_favourite': False, '_links'...  ...  3879670348
# 17  {'favourite': {'is_favourite': False, '_links'...  ...  4284678732
# 18  {'favourite': {'is_favourite': False, '_links'...  ...  2843152972
# 19  {'favourite': {'is_favourite': False, '_links'...  ...   152072780
# 20  {'favourite': {'is_favourite': False, '_links'...  ...   239805004
#
#    attractive_offer  price                                          price_czk  \
# 0                 0  27000  {'value_raw': 27000, 'unit': 'za měsíc', 'name...
# 1                 0   8000  {'value_raw': 8000, 'unit': 'za měsíc', 'name'...
# 2                 0  15000  {'value_raw': 15000, 'unit': 'za měsíc', 'name...
# 3                 0  15000  {'value_raw': 15000, 'unit': 'za měsíc', 'name...
# 4                 0  26000  {'value_raw': 26000, 'unit': 'za měsíc', 'name...
# 5                 0  31000  {'value_raw': 31000, 'unit': 'za měsíc', 'name...
# 6                 0  36000  {'value_raw': 36000, 'unit': 'za měsíc', 'name...
# 7                 0  27000  {'value_raw': 27000, 'unit': 'za měsíc', 'name...
# 8                 0  20000  {'value_raw': 20000, 'unit': 'za měsíc', 'name...
# 9                 0  21000  {'value_raw': 21000, 'unit': 'za měsíc', 'name...
# 10                0  25000  {'value_raw': 25000, 'unit': 'za měsíc', 'name...
# 11                0  87000  {'value_raw': 87000, 'unit': 'za měsíc', 'name...
# 12                0  50000  {'value_raw': 50000, 'unit': 'za měsíc', 'name...
# 13                0  41000  {'value_raw': 41000, 'unit': 'za měsíc', 'name...
# 14                0  43000  {'value_raw': 43000, 'unit': 'za měsíc', 'name...
# 15                0  56000  {'value_raw': 56000, 'unit': 'za měsíc', 'name...
# 16                0  41000  {'value_raw': 41000, 'unit': 'za měsíc', 'name...
# 17                0  28000  {'value_raw': 28000, 'unit': 'za měsíc', 'name...
# 18                0  46000  {'value_raw': 46000, 'unit': 'za měsíc', 'name...
# 19                0  17000  {'value_raw': 17000, 'unit': 'za měsíc', 'name...
# 20                0  27000  {'value_raw': 27000, 'unit': 'za měsíc', 'name...
#
#                                                _links    rus  \
# 0   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 1   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 2   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 3   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 4   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 5   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 6   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...   True
# 7   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 8   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 9   {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 10  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 11  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 12  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 13  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 14  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 15  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 16  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 17  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 18  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 19  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
# 20  {'dynamicDown': [{'href': 'https://d18-a.sdn.c...  False
#
#                                     name  region_tip  \
# 0               Pronájem bytu 1+kk 36 m²     3239160
# 1                 Pronájem  pokoje 20 m²           0
# 2               Pronájem bytu 1+kk 26 m²           0
# 3               Pronájem bytu 1+kk 28 m²           0
# 4                Pronájem bytu 3+1 92 m²           0
# 5               Pronájem bytu 2+kk 62 m²           0
# 6              Pronájem bytu 3+kk 119 m²           0
# 7               Pronájem bytu 2+kk 75 m²           0
# 8               Pronájem bytu 2+kk 69 m²           0
# 9               Pronájem bytu 2+kk 50 m²           0
# 10              Pronájem bytu 2+kk 50 m²           0
# 11    Pronájem bytu 5+1 250 m² (Mezonet)           0
# 12  Pronájem bytu 4+1 250 m² (Podkrovní)           0
# 13              Pronájem bytu 3+kk 94 m²           0
# 14              Pronájem bytu 3+kk 94 m²           0
# 15             Pronájem bytu 3+kk 125 m²           0
# 16             Pronájem bytu 4+kk 163 m²           0
# 17               Pronájem bytu 2+1 84 m²           0
# 18             Pronájem bytu 3+kk 115 m²           0
# 19              Pronájem bytu 1+kk 38 m²           0
# 20              Pronájem bytu 2+kk 51 m²           0
#
#                                                   gps  has_matterport_url
# 0   {'lat': 50.073473912870796, 'lon': 14.46310908...               False
# 1   {'lat': 50.00034291287079, 'lon': 14.468059087...               False
# 2   {'lat': 50.059329912870794, 'lon': 14.48421308...               False
# 3   {'lat': 50.06536791287079, 'lon': 14.471080087...               False
# 4   {'lat': 50.05818491287079, 'lon': 14.429304087...               False
# 5   {'lat': 50.04762591287079, 'lon': 14.292148087...               False
# 6   {'lat': 50.1262699128708, 'lon': 14.5648240871...               False
# 7   {'lat': 50.05613691287079, 'lon': 14.413430087...               False
# 8   {'lat': 50.05873091287079, 'lon': 14.399742087...               False
# 9   {'lat': 50.058493912870794, 'lon': 14.39670308...               False
# 10  {'lat': 50.059844912870794, 'lon': 14.40738908...               False
# 11  {'lat': 50.05212391287079, 'lon': 14.386497087...               False
# 12  {'lat': 50.07189891287079, 'lon': 14.427447087...               False
# 13  {'lat': 50.076758912870794, 'lon': 14.47587308...               False
# 14  {'lat': 50.076766912870795, 'lon': 14.47587608...               False
# 15  {'lat': 50.05675791287079, 'lon': 14.429233087...               False
# 16  {'lat': 50.060969912870796, 'lon': 14.45842608...               False
# 17  {'lat': 50.065180912870794, 'lon': 14.45035808...               False
# 18  {'lat': 50.0419759128708, 'lon': 14.4670230871...               False
# 19  {'lat': 50.117709912870794, 'lon': 14.44240308...               False
# 20  {'lat': 50.06213691287079, 'lon': 14.436303087...               False
#
# [21 rows x 27 columns]

# %% [markdown]
# ### 1b. Create a function converting sreality json data into pandas dataframe

# %%
df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 df = pd.DataFrame(data)
#
# File c:\Users\svest\anaconda3\Lib\site-packages\pandas\core\frame.py:733, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     727     mgr = self._init_mgr(
#     728         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     729     )
#     731 elif isinstance(data, dict):
#     732     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 733     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     734 elif isinstance(data, ma.MaskedArray):
#     735     from numpy.ma import mrecords
#
# File c:\Users\svest\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File c:\Users\svest\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File c:\Users\svest\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:680, in _extract_index(data)
#     677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
# --> 680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#     684 if have_series:
#     685     if lengths[0] != len(index):
#
# ValueError: Mixing dicts with non-Series may lead to ambiguous ordering.

# %%
def convert_sreality_data_to_df(sreality_data):
    raise NotImplemented

raw = convert_sreality_data_to_df(d)

# %% [markdown]
# ### 1c. link function `1b` into function `1a`

# %% [markdown]
# ### 1c. Combining multiple requests into single df
#
# * Function should parametrize:
#     * `start_page` and `end_page`
#     * request parameters
# * construct a list of individual request dfs
# * then feed it into `pd.concat` function

# %%
def request_multiply_sreality(start_page, end_page, category_main_str, category_type_str, locality_region_id=10):
    raise NotImplementedError

# %% [markdown]
# #### Task 2: Cleaning data
#
# __2a. Filter columns__
# * filter only columns: `['locality', 'price', 'name', 'gps','hash_id','exclusively_at_rk']`
# * use `.copy()` to avoid `SettingWithCopyWarning` later

# %% [markdown]
# Copy selection into new one

# %% [markdown]
# ### 2b: GPS
# * Convert dictionary in `gps` column into two columns - `lat` and `lon`
# * use apply function on gps column
# * Note apply can return multiple columns

# %% [markdown]
# ### 2c. Get flat type from name
#
# * Name is always represented by string `Prodej bytu [type of flat] [Area] m^2`
# * Try picking third word in string
# * Check meaningfulness using `.value_counts()`

# %%
# regular expression to find numbers before m²

# %%
# regular expression to find characters before '+' and behind '+'
def flat_type(x:str):
    # \d+ represents one or more digit(s)
    # \s is a space character
    # \w+ is one or more word character(s)
    # * represents 0 or more
    raise NotImplementedError

# %%
sample_text = 'Prodej bytu 3+kk 71 m²'
print(f"Initial text: {sample_text}")
print("Processed text:")

# %% [markdown]
# ### 2d. Get the area of a flat from name
#
# * Naive: select the word before last word
# * Then try navigating using the index of `'m²'`
# * If this also fail, then you will need to use regex - `import re`

# %%
def name_to_area(nm):
    raise NotImplementedError

# %% [markdown]
# __Check if the two areas are equal__
